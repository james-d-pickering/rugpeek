# %%
'''
function that filters through the spreadsheet to find files that
correspond to the same probe and wavelength

'''

# %matplotlib qt5
import rugpeek_functions as rp
import matplotlib.pyplot as plt
import numpy as np
import lmfit as lf
import matplotlib as mpl
import matplotlib.colors as colors
import sys
import pandas as pd
import re
import pprint

excel_data = pd.read_excel('Aarhus_Campaign_Jan_2024.xlsx', sheet_name=None)

sheet_names = excel_data.keys()
print(sheet_names)

#sheet2 = excel_data['Log']
#print(sheet2)

Log = pd.read_excel('Aarhus_Campaign_Jan_2024.xlsx', sheet_name='Log', skiprows=2)

filenames = Log['Filename']
#print(filenames)

list_of_files = []


for f in filenames:
    splitted = f.split('_')
    list_of_files.append(splitted)
    

#print(list_of_files) 
#^ this is as a list

allfiles = []

re.containsA = re.compile('nm|SHG')
re.containsB = re.compile('nm|FUN')
every_single_waveSHG =[]
every_single_waveFUN =[]

for file in list_of_files:
    for words in file:
        if re.containsA.match(words):
            #print('yesss', words)
            every_single_waveSHG.append(words)
        if re.containsB.match(words):
            every_single_waveFUN.append(words)

#print('Every single wave', every_single_wave)

SHG = []
FUN = []
for shgs in every_single_waveSHG:
    if shgs not in SHG:
        SHG.append(shgs)

for funs in every_single_waveFUN:
    if funs not in FUN:
        FUN.append(funs)
#print('\nRemoved duplicates', waves, '\n')

matchedSHG = []
matchedFUN = []


listofstrings = []
for file in filenames:
    splitting = file.split('_')
    newstring = ' '.join(map(str, splitting))
    listofstrings.append(newstring)

#print('\nNewstring:', listofstrings)

            
for s in SHG:
    for file in listofstrings:
        if (s in file):
            matchedSHG.append(file)
        
for f in FUN:
    for file in listofstrings:
        if (f in file):
            matchedFUN.append(file)
            
#print('matchedSHG', matchedSHG)
#print('\nmatchedFUN', matchedFUN)

SHG_listofstrings = []
for file in matchedSHG:
    SHG_listofstrings.append(file)
    
FUN_listofstrings = []
for file in matchedFUN:
    FUN_listofstrings.append(file)

#print('\nSHG strings',SHG_listofstrings)
#print('\nFUN strings',FUN_listofstrings)

newSHG_list = []
newFUN_list = []

for strings in SHG_listofstrings:
    s = strings.replace(' ', '_')
    newSHG_list.append(s)

for strings in FUN_listofstrings:
    s = strings.replace(' ', '_')
    newFUN_list.append(s)
    
#print('newfun list', newFUN_list)
SHGlist_spaces = []
FUNlist_spaces = []

for s in newSHG_list:
    splitted = s.split('_')
    SHGlist_spaces.append(splitted)
    
for f in newFUN_list:
    splitted = f.split('_')
    FUNlist_spaces.append(splitted)
    
every_single_waveSHG =[]
every_single_waveFUN =[]
re.containsZ = re.compile(r'.*nm.*')

for file in SHGlist_spaces:
    for words in file:
        if re.containsZ.match(words):
            every_single_waveSHG.append(words)

#print(FUNlist_spaces)
for file2 in FUNlist_spaces:
    #print(file2)
    for words in file2:
        if re.containsZ.match(words):
            every_single_waveFUN.append(words)

wavesSHG = []
wavesFUN = []

for wave in every_single_waveSHG:
    if wave not in wavesSHG:
        wavesSHG.append(wave)
        
for wave in every_single_waveFUN:
    if wave not in wavesFUN:
        wavesFUN.append(wave)
        
matchedSHG = {w: [] for w in wavesSHG}
matchedFUN = {w: [] for w in wavesFUN}

for wave in wavesSHG:
    for file in SHGlist_spaces:
        if (wave in file):
            string = ""
            for item in file:
                string = string + item+"_"
    
            string = string + "matrix"
            matchedSHG[wave].append(string)
            
for wave2 in wavesFUN:
    for file2 in FUNlist_spaces:
        if (wave2 in file2):
            matchedFUN[wave2].append(file2)
        
            
#print('all waves', every_single_wave)

#print('removed duplicates', wavesSHG)

#print('\nmatched SHG', matchedSHG)

#pprint.pprint(matchedSHG)
#pd.DataFrame(matchedSHG.items())
#x = pd.DataFrame.from_dict(matchedSHG, orient='index')
#print(x)
#print('\nmatched FUN', matchedFUN)

print('SHG\n')
pprint.pprint(matchedSHG)


print('\nFUN:\n')
pprint.pprint(matchedFUN)
# Out:
# dict_keys(['Packing List', 'Log', 'Overview', 'Sheet6', 'Misc', 'Sample prep'])
# SHG
#
# {'240nm': ['oxygenrelease_1mM_240nm_SHG_TA_1_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_2_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_3_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_1_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_2_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_3_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_4_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_5_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_6_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_7_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_8_matrix',
#            'oxygenrelease_1mM_240nm_SHG_TA_9_matrix',
#            'milliQ_240nm_SHG_chirp_1_matrix'],
#  '304nm': ['milliQ_304nm_SHG_chirp_1_matrix'],
#  '305nm': ['oxygenrelease_1mM_305nm_SHG_TA_1_matrix',
#            'oxygenrelease_1mM_305nm_SHG_TA_2_matrix',
#            'oxygenrelease_1mM_305nm_SHG_TA_3_matrix',
#            'oxygenrelease_1mM_305nm_SHG_TA_4_matrix',
#            'oxygenrelease_1mM_305nm_SHG_TA_5_matrix',
#            'oxygenrelease_1mM_305nm_SHG_TA_1_matrix'],
#  '350nm': ['Hemin_noligand_350nm_SHG_TA_1_matrix',
#            'Hemin_noligand_350nm_SHG_TA_2_matrix',
#            'Hemin_noligand_350nm_SHG_TA_2_matrix',
#            'milliQ_350nm_SHG_chirp_1_matrix',
#            'milliQ_350nm_SHG_chirp_2_matrix'],
#  '360nm': ['Haem-CYS_360nm_SHG_1_matrix',
#            'Haem-CYS_360nm_SHG_2_matrix',
#            'Haem-CYS_360nm_SHG_3_matrix',
#            'Haem-CYS_360nm_SHG_1kHz_1_matrix',
#            'Haem_360nm_SHG_1_matrix',
#            'Haem_360nm_SHG_2_matrix',
#            'Haem_360nm_SHG_Long_Delay_1_matrix',
#            'Haem_360nm_SHG_3_matrix',
#            'Haem-HIS_360nm_SHG_1_matrix',
#            'Haem_360nm_SHG_Repeat_1_matrix',
#            'Haem_360nm_SHG_Repeat_2_matrix',
#            'Haem_360nm_SHG_Repeat_3_matrix',
#            'Haem_360nm_SHG_Repeat_4_matrix'],
#  '371nm': ['Haem-CYS_371nm_SHG_1_matrix',
#            'Haem-CYS_371nm_SHG_2_matrix',
#            'Haem-CYS_371nm_SHG_3_matrix',
#            'Haem-CYS_371nm_SHG_4_matrix',
#            'Haem-CYS_371nm_SHG_5_matrix',
#            'Haem-CYS_371nm_SHG_6_matrix',
#            'Haem-CYS_371nm_SHG_7_matrix',
#            'Haem-CYS_371nm_SHG_8_matrix'],
#  '385nm': ['Haem_385nm_SHG_1_matrix',
#            'Haem_385nm_SHG_2_matrix',
#            'Haem_385nm_SHG_3_matrix',
#            'Haem_385nm_SHG_Repeat_1_matrix',
#            'Haem_385nm_SHG_Repeat_2_matrix',
#            'Haem_385nm_SHG_Repeat_3_matrix'],
#  '387nm': ['Hemin_noligand_387nm_SHG_TA_1_matrix',
#            'milliQ_387nm_SHG_chirp_1_matrix',
#            'milliQ_387nm_SHG_chirp_2_matrix'],
#  '400nm': ['oxygenrelease_1mM_400nm_SHG_TA_1_matrix',
#            'oxygenrelease_1mM_400nm_SHG_TA_2_matrix',
#            'oxygenrelease_1mM_400nm_SHG_TA_3_matrix',
#            'oxygenrelease_1mM_400nm_SHG_TA_4_matrix',
#            'milliQ_400nm_SHG_chirp_1_matrix',
#            'Haem-CYS_400nm_SHG_10Khz_1_matrix',
#            'Haem-CYS_400nm_SHG_10Khz_1_matrix'],
#  '406nm': ['Haem-HIS_406nm_SHG_1_matrix',
#            'Haem-HIS_406nm_SHG_2_matrix',
#            'Haem-HIS_406nm_SHG_3_matrix'],
#  '408nm': ['APX_80uM_408nm_SHG_TA_1_matrix',
#            'APX_80uM_408nm_SHG_TA_2_matrix',
#            'APX_80uM_408nm_SHG_TA_3_matrix'],
#  '409nm': ['Ferric-Mb_80uM_409nm_SHG_TA_1_matrix',
#            'Ferric-Mb_80uM_409nm_SHG_TA_2_matrix',
#            'FerricMb_80uM_409nm_SHG_10kHz_TA_1_matrix',
#            'FerricMb_80uM_409nm_SHG_10kHz_TA_2_matrix',
#            'FerricMb_80uM_409nm_SHG_10kHz_TA_3_matrix',
#            'milliQ_409nm_SHG_chirp_1_matrix'],
#  '416nm': ['OxyMb_80uM_416nm_SHG_TA_1_matrix',
#            'OxyMb_80uM_416nm_SHG_TA_2_matrix',
#            'OxyMb_80uM_416nm_SHG_TA_3_matrix',
#            'OxyMb_80uM_416nm_SHG_TA_4_matrix',
#            'milliQ_416nm_SHG_chirp_1_matrix'],
#  '435nm': ['Ferrous-Mb_100uM_435nm_SHG_TA_1_matrix',
#            'milliQ_435nm_SHG_chirp_1_matrix'],
#  '500nm': ['Ferric-Mb_80uM_500nm_SHG_TA_1_matrix',
#            'Ferric-Mb_80uM_500nm_SHG_TA_2_matrix',
#            'FerricMb_80uM_500nm_SHG_10kHz_TA_1_matrix',
#            'FerricMb_80uM_500nm_SHG_10kHz_TA_2_matrix',
#            'FerricMb_80uM_500nm_SHG_10kHz_TA_3_matrix',
#            'milliQ_500nm_SHG_chirp_1_matrix'],
#  '542nm': ['OxyMb_80uM_542nm_SHG_TA_1_matrix',
#            'OxyMb_80uM_542nm_SHG_TA_2_matrix',
#            'OxyMb_80uM_542nm_SHG_TA_1_matrix',
#            'OxyMb_80uM_542nm_SHG_3nsonwards_TA_1_matrix',
#            'OxyMb_80uM_542nm_SHG_3nsonwards_TA_2_matrix',
#            'OxyMb_80uM_542nm_SHG_3nsonwards_TA_3_matrix',
#            'OxyMb_80uM_542nm_SHG_1kHz_TA_1_matrix',
#            'OxyMb_80uM_542nm_SHG_5kHz_TA_1_matrix',
#            'OxyMb_80uM_542nm_SHG_2kHz_TA_1_matrix',
#            'milliQ_542nm_SHG_chirp_1_matrix'],
#  '556nm': ['Ferrous-Mb_100uM_556nm_SHG_TA_1_matrix',
#            'Ferrous-Mb_100uM_556nm_SHG_TA_2_matrix',
#            'Ferrous-Mb_100uM_556nm_SHG_TA_3_matrix',
#            'milliQ_556nm_SHG_chirp_1_matrix'],
#  '581nm': ['OxyMb_80uM_581nm_SHG_TA_1_matrix',
#            'OxyMb_80uM_581nm_SHG_TA_2_matrix',
#            'OxyMb_80uM_581nm_SHG_TA_3_matrix',
#            'milliQ_581nm_SHG_chirp_1_matrix'],
#  '630nm': ['Ferric-Mb_80uM_630nm_SHG_TA_1_matrix',
#            'milliQ_630nm_SHG_chirp_1_matrix']}
#
# FUN:
#
# {'360nm': [['Haem-CYS', '360nm', 'FUN', '10kHz', '1'],
#            ['Haem-CYS', '360nm', 'FUN', '10kHz', '2'],
#            ['Haem-CYS', '360nm', 'FUN', '10kHz', '3'],
#            ['Haem', '360nm', 'FUN', '1'],
#            ['Haem', '360nm', 'FUN', '2']],
#  '368nm': [['Haem-CYS', '368nm', 'FUN', '1'],
#            ['Haem-CYS', '368nm', 'FUN', 'Long-Delay', '1'],
#            ['Haem-CYS', '368nm', 'FUN', 'Long-Delay', '2'],
#            ['Haem-CYS', '368nm', 'FUN', '2']],
#  '371nm': [['Haem-CYS', '371nm', 'FUN', '1'],
#            ['Haem-CYS', '371nm', 'FUN', '2'],
#            ['Haem-CYS', '371nm', 'FUN', '3'],
#            ['Haem-CYS', '371nm', 'FUN', '4']],
#  '385nm': [['Haem', '385nm', 'FUN', '1']],
#  '387nm': [['Hemin', 'noligand', '387nm', 'FUN', 'TA', '1'],
#            ['Hemin', 'noligand', '387nm', 'FUN', 'TA', '2'],
#            ['milliQ', '387nm', 'FUN', 'chirp', '1']],
#  '400nm': [['milliQ', '400nm', 'FUN', 'chirp', '1'],
#            ['Haem-CYS', '400nm', 'FUN', '10kHz', '1'],
#            ['Haem-CYS', '400nm', 'FUN', '2'],
#            ['Haem-CYS', '400nm', 'FUN', '3']],
#  '409nm': [['Ferric-Mb', '80uM', '409nm', 'FUN', 'TA', '1'],
#            ['Ferric-Mb', '80uM', '409nm', 'FUN', 'TA', '2'],
#            ['FerricMb', '80uM', '409nm', 'FUN', '10kHz', 'TA', '1'],
#            ['FerricMb', '80uM', '409nm', 'FUN', '10kHz', 'TA', '2'],
#            ['FerricMb', '80uM', '409nm', 'FUN', '10kHz', 'TA', '3'],
#            ['FerricMb', '80uM', '409nm', 'FUN', '10kHz', 'TA', '4'],
#            ['FerricMb', '80uM', '409nm', 'FUN', '10kHz', 'TA', '5'],
#            ['milliQ', '409nm', 'FUN', 'chirp', '1']],
#  '416nm': [['OxyMb', '100uM', '416nm', 'FUN', 'TA', '1'],
#            ['OxyMb', '100uM', '416nm', 'FUN', 'TA', '1', 'random'],
#            ['OxyMb', '80uM', '416nm', 'FUN', 'TA', '1'],
#            ['OxyMb', '80uM', '416nm', 'FUN', 'TA', '2'],
#            ['OxyMb', '80uM', '416nm', 'FUN', 'TA', '3'],
#            ['milliQ', '416nm', 'FUN', 'chirp', '1']],
#  '435nm': [['Ferrous-Mb', '100uM', '435nm', 'FUN', 'TA', '1'],
#            ['Ferrous-Mb', '100uM', '435nm', 'FUN', 'TA', '2'],
#            ['milliQ', '435nm', 'FUN', 'chirp', '1']],
#  '500nm': [['Ferric-Mb', '80uM', '500nm', 'FUN', 'TA', '1'],
#            ['Ferric-Mb', '80uM', '500nm', 'FUN', 'TA', '2'],
#            ['milliQ', '500nm', 'FUN', 'chirp', '1']],
#  '542nm': [['OxyMb', '100uM', '542nm', 'FUN', 'TA', '1'],
#            ['OxyMb', '100uM', '542nm', 'FUN', 'TA', '2'],
#            ['OxyMb', '100uM', '542nm', 'FUN', 'TA', '3'],
#            ['OxyMb', '100uM', '542nm', 'FUN', 'TA', 'lissajous'],
#            ['milliQ', '542nm', 'FUN', 'chirp', '1']],
#  '556nm': [['Ferrous-Mb', '100uM', '556nm', 'FUN', 'TA', '1'],
#            ['Ferrous-Mb', '100uM', '556nm', 'FUN', 'TA', '2'],
#            ['milliQ', '556nm', 'FUN', 'chirp', '1']],
#  '581nm': [['OxyMb', '100uM', '581nm', 'FUN', 'TA', '1'],
#            ['OxyMb', '100uM', '581nm', 'FUN', 'TA', '2'],
#            ['milliQ', '581nm', 'FUN', 'chirp', '1']],
#  '630nm': [['Ferric-Mb', '80uM', '630nm', 'FUN', 'TA', '1'],
#            ['milliQ', '630nm', 'FUN', 'chirp', '1']]}

# %%
'''
I think it unzips everything here and the folders within the zip
should then appear in your directory

attached an image below of what shows up

'''

import glob
import re
from zipfile import ZipFile

zipfile = glob.glob('*zip')
print(zipfile)

filelist = glob.glob('*.dat')

zips = [] 
with ZipFile('aarhus_TA_jan24.zip', 'r') as zipObj:
    for entry in zipObj.infolist():
        #print(entry.filename)
        zips.append(entry.filename)  

#print(zips) #every thing in the zip folder- even the folders within it

# %% [markdown]
# ![image130724.png](attachment:image130724.png)

# %%
data = (matchedSHG['240nm'])
print(data)
rp.Rug.auto_processing(data)
# Out:
# ['oxygenrelease_1mM_240nm_SHG_TA_1_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_2_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_3_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_1_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_2_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_3_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_4_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_5_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_6_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_7_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_8_matrix', 'oxygenrelease_1mM_240nm_SHG_TA_9_matrix', 'milliQ_240nm_SHG_chirp_1_matrix']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\2441515783.py in <module>
#       1 data = (matchedSHG['240nm'])
#       2 print(data)
# ----> 3 rp.Rug.auto_processing(data)
#
# ~\Untitled Folder\rugpeek_functions.py in auto_processing(files, solventstring, background, correct_dispersion, offset)
#    1175             if solventstring in file:
#    1176                 solventfile = file
# -> 1177                 solventdata = Rug(solventfile, ".dat")
#    1178
#    1179         files.pop(0)
#
# ~\Untitled Folder\rugpeek_functions.py in __init__(self, fname, extension)
#     438         """
#     439
# --> 440         self.wavelengths, self.times, self.matrix = RugTools.read_harpia_matrix(fname, extension)
#     441         self.filename = os.path.basename(fname)
#     442
#
# ~\Untitled Folder\rugpeek_functions.py in read_harpia_matrix(file, extension)
#      58     # not divided into individual scans
#      59         count = 0
# ---> 60         with open(file+extension, encoding="utf-8") as f:
#      61             for line in f:
#      62
#
# FileNotFoundError: [Errno 2] No such file or directory: 'milliQ_240nm_SHG_chirp_1_matrix.dat'

# %%
'''
Another extraction function I was looking at 

'''
import zipfile
import os

with zipfile.ZipFile('aarhus_TA_jan24.zip', "r") as zf:
        for name in zf.namelist():
            localFilePath = zf.extract(name, '')
            if os.path.isdir(localFilePath):
                continue
            print(localFilePath)
# Out:
# 2024-01-08\Mb_impure_1_TA_1.dat
# 2024-01-08\Mb_impure_1_TA_2.dat
# 2024-01-08\Mb_impure_1_TA_3.dat
# 2024-01-18\Haem_360nm_FUN_TA_2.dat
# 2024-01-18\Haem_360nm_SHG_TA_3.dat
# 2024-01-18\Haem_360nm_FUN_TA_1.dat
# 2024-01-18\Haem_360nm_SHG_TA_1.dat
# 2024-01-18\Haem_360nm_SHG_TA_2.dat
# 2024-01-18\Haem_385nm_FUN_TA_1.dat
# 2024-01-18\Haem_385nm_SHG_TA_1.dat
# 2024-01-18\Haem_385nm_SHG_TA_2.dat
# 2024-01-18\Haem_385nm_SHG_TA_3.dat
# 2024-01-08\Mb_impure_100um_409nm.dat
# 2024-01-08\Mb_impure_1_TA_1_stats.dat
# 2024-01-08\Mb_impure_1_TA_2_stats.dat
# 2024-01-08\Mb_impure_1_TA_3_stats.dat
# 2024-01-19\Haem-CYS_371nm_FUN_TA_1.dat
# 2024-01-19\Haem-CYS_371nm_FUN_TA_2.dat
# 2024-01-19\Haem-CYS_371nm_FUN_TA_3.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_4.dat
# 2024-01-19\Haem-CYS_371nm_FUN_TA_4.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_2.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_3.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_5.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_1.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_6.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA_7.dat
# 2024-01-19\Haem-CYS_371nm_SHG_TA
dat
# 2024-01-12\OxyMb_80uM_542nm_SHG_3nsonwards_TA_3_stats.dat
# 2024-01-08\Mb_impure_100uM_500nm_longregion_TA_2_stats.dat
# 2024-01-11\OxyMb_100uM_542nm_FUN_lissajous_TA_1_matrix.dat
# 2024-01-12\OxyMb_80uM_542nm_SHG_3nsonwards_TA_1_matrix.dat
# 2024-01-12\OxyMb_80uM_542nm_SHG_3nsonwards_TA_2_matrix.dat
# 2024-01-12\OxyMb_80uM_542nm_SHG_3nsonwards_TA_3_matrix.dat
# 2024-01-08\Mb_impure_100uM_500nm_longregion_TA_2_matrix.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem_360nm_SHG_TA_2.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_TA_2.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem_360nm_SHG_TA_2_stats.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_1_TA_1.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem_360nm_SHG_TA_2_matrix.dat
# 2024-01-08\spectest_0_pumped (712 spectra)_0_pumped (715 spectra).txt
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_TA_2_stats.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_TA_2_matrix.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_1_TA_1_stats.dat
# 2024-01-08\spectest_0_pumped (712 spectra)_1_not pumped (737 spectra).txt
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_1_TA_1_matrix.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_1.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_2.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_1_stats.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_2_stats.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_1_matrix.dat
# 2024-01-17\Haem-Cys_rerun_post_uvvis\Haem-CYS_368nm_FUN_Long-Delay_TA_2_matrix.dat

# %%
'''
function that loops through the matchedshg['240nm'] files, makes the
name a keyword to search and then loops through the subfolder files to
see if they match up. If they do match up then the autoprocessing should
run. Doesn't work :p

I thought this would get around the issue of the files from the
subfolders not being found but I think it's something else that's
causing the problem.

'''
filelist = glob.glob('*.dat')
files_in_subfolders = glob.glob('**/*.dat')

#print(files_in_subfolders)

data = (matchedSHG['240nm'])
for i in data: ####### looks at each file
    filefinder = "r'.*" + i + ".*'" ## puts the special charcacters
    re.containsi = re.compile(filefinder) 
    for files in files_in_subfolders:
        if re.containsi.match(file): #if it contains the same name as the 
            rp.Rug.auto_processing(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20400\575008827.py in <module>
#      18     re.containsi = re.compile(filefinder)
#      19     for files in files_in_subfolders:
# ---> 20         if re.containsi.match(file): #if it contains the same name as the
#      21             rp.Rug.auto_processing(file)
#
# TypeError: expected string or bytes-like object
